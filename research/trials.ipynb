# %%
import gdown

# %%
url = 'https://drive.google.com/file/d/1w_rMpEHM4itYXSTgjwm0i5dUcFI2luZL/view?usp=drive_link'
id = url.split('/')[-2]

# %%
prefix = 'https://drive.google.com/uc?id='
gdown.download(prefix+id, 'data.csv', quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1w_rMpEHM4itYXSTgjwm0i5dUcFI2luZL
# From (redirected): https://drive.google.com/uc?id=1w_rMpEHM4itYXSTgjwm0i5dUcFI2luZL&confirm=t&uuid=57432034-df23-4fed-9f83-ab72d4ad148c
# To: c:\Users\PRATHAM\Desktop\Programming\NLP-DS\Kidney-Disease-classification\research\data.csv
# 100%|██████████| 2.29G/2.29G [06:24<00:00, 5.96MB/s]
# 'data.csv'
